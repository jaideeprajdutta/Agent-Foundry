# %%
###Document structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is a sample document content",
    metadata={
        "source": "sample.txt",
        "pages":100,
        "author":"jai"
        }
)
print(doc)
# Out:
# page_content='This is a sample document content' metadata={'source': 'sample.txt', 'pages': 100, 'author': 'jai'}

# %%
import os

# %%
#Text Loader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("RAG\\notebook\\sample_text\\movies.txt")
doc = loader.load()
print(doc)
# Out:
# [Document(metadata={'source': 'C:\\Users\\jaide\\OneDrive\\Desktop\\Projects\\Agent Foundry\\RAG\\notebook\\sample_text\\movies.txt'}, page_content="Movies are a profound form of mass media and art that blend visual and auditory storytelling to evoke deep emotion and convey complex narratives. Emerging in the late 19th century, cinema quickly grew into a cultural phenomenon that shapes societal values, drives global entertainment, and offers audiences a universal medium for catharsis.The Evolution of CinemaFrom the silent, flickering reels of early 20th-century film to today's high-budget global blockbusters, the medium has evolved dramatically. Historically, the industry was dominated by a few major Hollywood studios. However, the landscape has democratized significantly.Independent Filmmaking: Advancements in technology have made it easier to produce low-budget, independent films that challenge traditional narratives.Global Reach: International cinema has surged in prominence. Regions like South India have witnessed a massive global footprint in recent years.Streaming vs. Theaters: The rise of streaming giants has altered distribution, with companies occasionally balancing theatrical releases with digital viewing.Why Movies MatterBeyond mere entertainment, films are influential cultural artifacts that reflect and affect the societies that create them.Social and Emotional Impact: Research indicates that humanistically oriented films help develop interpersonal communication skills, increase ethnic tolerance, and foster empathy among youth.Psychological Catharsis: Iconic cinematic narratives provide compelling myths that help audiences resolve personal tensions and make sense of their everyday lives.Critical Discourse: The democratization of online criticism has elevated film discourse, ensuring that both high-art and crowd-pleasing mainstream films find dedicated audiences.The Future of FilmmakingThe cinematic landscape continues to adapt, driven by evolving technology, shifting audience expectations, and a continuous hunger for meaningful or adventurous storytelling. As platforms diversify, the core power of a compelling story remains central.To explore current cinematic trends and critical perspectives, you can review ongoing discussions on platforms like The New Yorker or discover the latest releases via The New York Times.If you are writing an article or studying film, tell me:What specific genre or era of movies are you focusing on (e.g., sci-fi, 1970s Hollywood, independent)?Are you looking to explore filmmaking techniques or cultural impact?I can help you outline a custom, in-depth piece or recommend further reading.")]
