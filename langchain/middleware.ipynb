# %% [markdown]
# Middleware
# these basically provide a way to more tightly control what happens inside the agent. Like such as:
#
# - Tracking agent behavior with logging, analytics, and debugging.
# - Transforming prompts, tool selection, and output formatting.
# - Adding retries, fallbacks, and early termination logic.
# - Applying rate limits, guardrails, and PII detection.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENROUTER_API_KEY"] = os.getenv("OPENROUTER_API_KEY")

# %% [markdown]
# Summarization Middleware
# Automatically summarize conversation history when approaching token limits, preserving recent messages while compressing older context.

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import AgentMiddleware, SummarizationMiddleware
from langchain_core.messages import HumanMessage, SystemMessage

#msg summarization

agent = create_agent(
    model = "openrouter:qwen/qwen3-32b",
    middleware=[
        SummarizationMiddleware(
            model = "gemini:gemini-2.0-flash-exp",
            max_tokens=1000,
            max_tokens_before_summary=1000,
            max_summary_tokens=1000,
            trigger=("token_count", 1000)
        )
    ]
)
