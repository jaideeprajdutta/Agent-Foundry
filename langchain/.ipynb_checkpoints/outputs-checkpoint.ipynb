# %% [markdown]
# Structured output
#
# Pydantic,
# TypedDict,
# Dataclass

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["OPENROUTER_API_KEY"]=os.getenv("OPENROUTER_API_KEY")
model=init_chat_model("openrouter:qwen/qwen3-32b")

response = model.invoke("hello, how are you")
print(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import os
#       2 from langchain.chat_models import init_chat_model
# ----> 3 os.environ["OPENROUTER_API_KEY"]=os.getenv("OPENROUTER_API_KEY")
#       4 model=init_chat_model("openrouter:qwen/qwen3-32b")
#       5
#       6 response = model.invoke("hello, how are you")
#
# File <frozen os>:721, in _Environ.__setitem__(self, key, value)
#     719 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen os>:781, in _createenviron.<locals>.check_str(value)
#     779 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: str expected, not NoneType

# %%
import os
print(os.getenv("OPENROUTER_API_KEY"))
# Out:
# None

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True
